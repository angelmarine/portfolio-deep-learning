# %%
import matplotlib.pyplot as plt
import json

# %%
filenames = ['LSTM', 'Random', 'Uniform', 'PG_new', 'Loser_new', 'UCRP_new', 'Winner_new']

# %%
for filename in filenames:
    path = filename + ".txt"
    f = open(path, 'r')
    data = json.load(f)
    print(len(data))
    plt.plot(range(len(data)), data, label=filename)

plt.xlabel('Days')
plt.ylabel('Value in US Dollars')
plt.title('Portfolio Performances')
plt.legend()
plt.show()
# Out:
# 148
# 148
# 148
# 148
# 148
# 148
# 148
